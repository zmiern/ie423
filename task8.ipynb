# %% [markdown]
# <a href="https://colab.research.google.com/github/zmiern/ie423/blob/main/task8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dfjoke = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/JokeText.csv')

dfrtng1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/UserRatings1.csv')
dfrtng2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/UserRatings2.csv')

# %%
dfrtng1.head()

# %%
dfrtng2.head()

# %%
dfjoke.head()
# Out:
#    JokeId                                           JokeText
# 0       0  A man visits the doctor. The doctor says "I ha...
# 1       1  This couple had an excellent relationship goin...
# 2       2  Q. What's 200 feet long and has 4 teeth? \n\nA...
# 3       3  Q. What's the difference between a man and a t...
# 4       4  Q.\tWhat's O. J. Simpson's Internet address? \...

# %%
dfjoke.info()

# %%
dfj.describe()

# %%
dfjoke.drop_duplicates(subset ='JokeId', keep = 'first', inplace = True)
dfjoke.shape
# Out:
# (100, 2)

# %%
dfjoke.drop_duplicates()
# Out:
#     JokeId                                           JokeText
# 0        0  A man visits the doctor. The doctor says "I ha...
# 1        1  This couple had an excellent relationship goin...
# 2        2  Q. What's 200 feet long and has 4 teeth? \n\nA...
# 3        3  Q. What's the difference between a man and a t...
# 4        4  Q.\tWhat's O. J. Simpson's Internet address? \...
# ..     ...                                                ...
# 95      95  Two attorneys went into a diner and ordered tw...
# 96      96  A teacher is explaining to her class how diffe...
# 97      97  Age and Womanhood\n\n1. Between the ages of 13...
# 98      98  A bus station is where a bus stops.\nA train s...
# 99      99  Q: Whats the difference between greeting a Que...
#
# [100 rows x 2 columns]

# %%
# !pip install scikit-learn==1.2.2
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 27.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
mdlTfvMvs = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = mdlTfvMvs.fit_transform(dfjoke['JokeText'])
tfidf_matrix.shape
# Out:
# (100, 3774)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
cosine_sim.shape
# Out:
# (100, 100)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Vectorizing Joke Text via TfidVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(dfjoke['JokeText'])

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
titles = dfjoke['JokeText']
indices = pd.Series(dfjoke.index, index=dfjoke['JokeText'])

def get_recommendations(joke_text):
    idx = indices[joke_text]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    joke_indices = [i[0] for i in sim_scores]
    return titles.iloc[joke_indices]

example_joke = dfjoke['JokeText'].iloc[0]
recommended_jokes = get_recommendations(example_joke).head(10)

recommended_jokes
# Out:
# 86    A man, recently completing a routine physical ...
# 67    A man piloting a hot air balloon discovers he ...
# 87    A Czechoslovakian man felt his eyesight was gr...
# 75    There once was a man and a woman that both  go...
# 31    A man arrives at the gates of heaven. St. Pete...
# 38    What is the difference between men and women:\...
# 55    A man and Cindy Crawford get stranded on a des...
# 80    An Asian man goes into a New York CityBank to ...
# 32    What do you call an American in the finals of ...
# 3     Q. What's the difference between a man and a t...
# Name: JokeText, dtype: object

# %%
dfrtng.head(10)
# Out:
#    JokeId  User1  User2  User3  User4  User5  User6  User7  User8  User9  ...  \
# 0       0   5.10  -8.79  -3.50   7.14  -8.79   9.22  -4.03   3.11  -3.64  ...
# 1       1   4.90  -0.87  -2.91  -3.88  -0.58   9.37  -1.55   0.92  -3.35  ...
# 2       2   1.75   1.99  -2.18  -3.06  -0.58  -3.93  -3.64   7.52  -6.46  ...
# 3       3  -4.17  -4.61  -0.10   0.05   8.98   9.27  -6.99   0.49  -3.40  ...
# 4       4   5.15   5.39   7.52   6.26   7.67   3.45   5.44  -0.58   1.26  ...
# 5       5   1.75  -0.78   1.26   6.65   8.25  -8.11  -6.75   2.14   0.34  ...
# 6       6   4.76   1.60  -5.39  -7.52   4.08   4.42  -0.15  -0.24  -3.01  ...
# 7       7   3.30   1.07   1.50   7.28   2.52   2.72  -5.87   8.06  -6.65  ...
# 8       8  -2.57  -8.69  -8.40  -5.15  -9.66   9.08  -3.54   2.82  -3.40  ...
# 9       9  -1.41  -4.66   4.37  -7.14   2.48   9.13  -5.19   7.52   1.36  ...
#
#    User36701  User36702  User36703  User36704  User36705  User36706  \
# ...

# %%
dfjoke.shape
# Out:
# (100, 2)

# %%
dfjoke.drop_duplicates(subset ='JokeText', keep = 'first', inplace = True)
dfjoke.shape
# Out:
# (100, 2)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
mdlTfvMvs = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=1, stop_words='english')
tfidf_matrix = mdlTfvMvs.fit_transform(dfjoke['JokeText'])
tfidf_matrix.shape
# Out:
# (100, 3774)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
cosine_sim.shape
# Out:
# (100, 100)

# %%
dfjoke['JokeId'] = dfjoke['JokeId'].astype(str)
titles = dfjoke['JokeId']
indices = pd.Series(dfjoke.index, index=dfjoke['JokeId'])

def get_recommendations(JokeText):
    idx = indices[JokeText]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations("1").head(10)
# Out:
# 45    45
# 52    52
# 37    37
# 92    92
# 67    67
# 22    22
# 64    64
# 44    44
# 75    75
# 13    13
# Name: JokeId, dtype: object

# %%
get_recommendations('5').head(10)
# Out:
# 98    98
# 79    79
# 26    26
# 91    91
# 60    60
# 30    30
# 45    45
# 52    52
# 75    75
# 44    44
# Name: JokeId, dtype: object

# %%
dfrtng.head(10)
# Out:
#    JokeId  User1  User2  User3  User4  User5  User6  User7  User8  User9  ...  \
# 0       0   5.10  -8.79  -3.50   7.14  -8.79   9.22  -4.03   3.11  -3.64  ...
# 1       1   4.90  -0.87  -2.91  -3.88  -0.58   9.37  -1.55   0.92  -3.35  ...
# 2       2   1.75   1.99  -2.18  -3.06  -0.58  -3.93  -3.64   7.52  -6.46  ...
# 3       3  -4.17  -4.61  -0.10   0.05   8.98   9.27  -6.99   0.49  -3.40  ...
# 4       4   5.15   5.39   7.52   6.26   7.67   3.45   5.44  -0.58   1.26  ...
# 5       5   1.75  -0.78   1.26   6.65   8.25  -8.11  -6.75   2.14   0.34  ...
# 6       6   4.76   1.60  -5.39  -7.52   4.08   4.42  -0.15  -0.24  -3.01  ...
# 7       7   3.30   1.07   1.50   7.28   2.52   2.72  -5.87   8.06  -6.65  ...
# 8       8  -2.57  -8.69  -8.40  -5.15  -9.66   9.08  -3.54   2.82  -3.40  ...
# 9       9  -1.41  -4.66   4.37  -7.14   2.48   9.13  -5.19   7.52   1.36  ...
#
#    User36701  User36702  User36703  User36704  User36705  User36706  \
# ...

# %%
# !pip3 install scikit-surprise
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import train_test_split
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 1.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357286 sha256=7990ac4c0d357beaf7ab75ae207e6e3b45d7ad5a5090d493d16acf25567e1148
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# ...

# %%
df_long = dfrtng.melt(id_vars=['JokeId'], var_name='User', value_name='Rating')

df_long = df_long.dropna(subset=['Rating'])

df_long['JokeId'] = df_long['JokeId'].astype(str)
df_long['User'] = df_long['User'].astype(str)

reader = Reader(rating_scale=(0, 5))
X = Dataset.load_from_df(df_long[['User', 'JokeId', 'Rating']], reader)

X_train, X_test = train_test_split(X, test_size=.25)

print(df_long)
# Out:
#         JokeId       User  Rating
# 0            0      User1    5.10
# 1            1      User1    4.90
# 2            2      User1    1.75
# 3            3      User1   -4.17
# 4            4      User1    5.15
# ...        ...        ...     ...
# 3670967     67  User36710    3.59
# 3670968     68  User36710    5.39
# 3670969     69  User36710    4.71
# 3670980     80  User36710    0.97
# 3670984     84  User36710    1.26
#
# [3012090 rows x 3 columns]

# %%
from surprise import SVD

mdlSvdrtng = SVD()

# %%
mdlSvdrtng.fit(X_train)
test_pred = mdlSvdrtng.test(X_test)

# %%
from surprise import accuracy

accuracy.rmse(test_pred)
# Out:
# RMSE: 4.6267
# 4.6267294685968245

# %%
from surprise.model_selection import GridSearchCV

param_grid = {'n_epochs': [5, 10, 15], 'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)

gs.fit(X)

print(gs.best_score['rmse'])

print(gs.best_params['rmse'])
# Out:
# 4.693929617999076
# {'n_epochs': 15, 'lr_all': 0.005, 'reg_all': 0.4}

# %%
from surprise.model_selection import cross_validate

cross_validate(mdlSvdrtng, X, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    4.6308  4.6245  4.6337  4.6376  4.6353  4.6324  0.0045
# MAE (testset)     3.6847  3.6785  3.6832  3.6888  3.6866  3.6844  0.0035
# Fit time          70.15   62.78   56.14   56.18   55.25   60.10   5.70
# Test time         21.67   9.44    8.44    9.24    10.92   11.94   4.93
# {'test_rmse': array([4.63083909, 4.62449582, 4.63374085, 4.63762577, 4.63525128]),
#  'test_mae': array([3.68474544, 3.67853634, 3.68320164, 3.68884636, 3.68656805]),
#  'fit_time': (70.14625549316406,
#   62.77727437019348,
#   56.13977599143982,
#   56.18461632728577,
#   55.252156496047974),
#  'test_time': (21.66951823234558,
#   9.440199375152588,
#   8.440670013427734,
#   9.243299007415771,
#   10.918941736221313)}

# %%
df_long[df_long['User'] == 'User19072']
# Out:
#         JokeId       User  Rating
# 1907100      0  User19072    1.12
# 1907101      1  User19072    1.21
# 1907102      2  User19072    8.69
# 1907103      3  User19072   -1.65
# 1907104      4  User19072    1.80
# ...        ...        ...     ...
# 1907169     69  User19072   -4.81
# 1907172     72  User19072   -7.14
# 1907179     79  User19072   -3.50
# 1907182     82  User19072   -5.24
# 1907193     93  User19072    8.88
#
# [74 rows x 3 columns]

# %%
mdlSvdrtng.predict(98, 19072)
# Out:
# Prediction(uid=98, iid=19072, r_ui=None, est=0.7812744307109021, details={'was_impossible': False})
